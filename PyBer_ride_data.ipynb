# %%
# %matplotlib inline
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Load in csv
pyber_ride_df = pd.read_csv("Resources/PyBer_ride_data.csv")
pyber_ride_df
# Out:
#     Month  Avg. Fare ($USD)
# 0     Jan             10.02
# 1     Feb             23.24
# 2     Mar             39.20
# 3   April             35.42
# 4     May             32.34
# 5    June             27.04
# 6    July             43.82
# 7     Aug             10.56
# 8    Sept             11.85
# 9     Oct             27.90
# 10    Nov             20.71
# 11    Dec             20.09

# %%
# Set x-axis and tick locations.
x_axis = np.arange(len(pyber_ride_df))
tick_locations = [value for value in x_axis]
# Plot the data.
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)")
plt.xticks(tick_locations, pyber_ride_df["Month"])
plt.show()

# %%
pyber_ride_df.plot.bar(x="Month", y="Avg. Fare ($USD)")
plt.show()

# %%
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)", kind='bar')
plt.errorbar(x=pyber_ride_df["Month"], y=pyber_ride_df["Avg. Fare ($USD)"])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/vj/j1gz7xb54fs53mbydb18bmjr0000gn/T/ipykernel_39413/1991632271.py in <module>
# ----> 1 pyber_ride_df.plot.bar(x="Month", y="Avg. Fare ($USD)", kind='bar')
#       2 plt.errorbar(x=pyber_ride_df["Month"], y=pyber_ride_df["Avg. Fare ($USD)"])
#       3
#       4 plt.show()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/plotting/_core.py in bar(self, x, y, **kwargs)
#    1128         other axis represents a measured value.
#    1129         """
# -> 1130         return self(kind="bar", x=x, y=y, **kwargs)
#    1131
#    1132     @Appender(
#
# TypeError: PlotAccessor object got multiple values for keyword argument 'kind'

# %%
import statistics

# %%
# Out:
# <ErrorbarContainer object of 3 artists>
